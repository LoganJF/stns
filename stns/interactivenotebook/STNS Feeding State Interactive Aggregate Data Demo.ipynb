# %% [markdown]
# # Purpose of this notebook:
# The purpose of this notebook is to plot aggregated data of Fed and Unfed STNS during saline, unfed hemolymph, and fed hemolymph incubations following dpon stimulation
#
# Notes: this is simply an initial demo to test that the interactive features and hosting still will work with upgraded env.

# %% [markdown]
# # Load Required Packages

# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib.lines import Line2D
from matplotlib import pyplot as plt
from collections import OrderedDict
from IPython.display import display
from glob import glob
# Widget stuff
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, fixed, interactive

# Logan Stuff
#from stns import (max_burst_number, condition_plot, paired_plots)

# %%
# %matplotlib inline
# Loading Data
data = pd.read_csv('STNS_Feeding_State_Hemo_all_bursts.csv')
data_apples = pd.read_csv('STNS_Feeding_State_Hemo_apples2apples_bursts.csv')
data = data.drop(columns='Unnamed: 0')#, 'Unnamed: 0.1'])
data_apples = data_apples.drop(columns='Unnamed: 0')#, 'Unnamed: 0.1'])
dataframe = data

print('Summary Statistics:Median')
display(dataframe.groupby(['Date', 'Neuron', 'Condition'], as_index=True).median())

# Create dictionarys for plotting usuage. 
dates=list(dataframe['Date'].unique())
Conditions = list(dataframe['Condition'].unique())
markers = Line2D.filled_markers[:5]
cmap=sns.color_palette('colorblind',5)
marker_d = dict(zip(sorted(dataframe['Date'].unique()),markers))
color_d = dict(zip(sorted(dataframe['Date'].unique()), cmap))

cond_options = dataframe.Condition.unique()
y_val_options = ['Burst Duration (sec)', '# of Spikes',
               'Spike Frequency (Hz)', 'Instantaneous Period (sec)',
               'Instantaneous Frequency (Hz)','Duty Cycle']
neuron_options = ['LG', 'DG', 'GM', 'MG', 'MCN1R', 'MCN1L']
kind = ['violin', 'line', 'scatter', 'paired', 'isi', 'strip']
# Out:
# Summary Statistics:Median
#                                        Burst Order  Burst Duration (s)  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo            4.0            3.836430
#                 Fed STNS\n Saline 0           22.0            4.586220
#                 Fed STNS\n Saline 1           20.5            6.572880
#          LG     Fed STNS\n Fed Hemo            2.5            3.370140
#                 Fed STNS\n Saline 0           20.5            6.859485
#                 Fed STNS\n Saline 1           18.5            6.864075
#          MCN1R  Fed STNS\n Fed Hemo           26.5            0.028080
#                 Fed STNS\n Saline 0           97.0            0.732780
#                 Fed STNS\n Saline 1          210.5            0.564975
# 11-18-21 DG     Unfed STNS\n Fed Hemo         11.5            4.058100
#                 Unfed STNS\n Saline 0         39.0            5.452380
#                 Unfed STNS\n Saline 1         24.0            3.060180
#          LG     Unfed STNS\n Fed Hemo         11.5            3.879765
#                 Unfed STNS\n Saline 0         38.0            4.854330
#                 Unfed STNS\n Saline 1         23.5            4.894560
#          MCN1L  Unfed STNS\n Fed Hemo         81.5            1.045170
#                 Unfed STNS\n Saline 0        476.0            0.678240
#                 Unfed STNS\n Saline 1         47.0            2.914380
#          MCN1R  Unfed STNS\n Fed Hemo         70.5            0.244755
#                 Unfed STNS\n Saline 0        186.5            0.397845
#                 Unfed STNS\n Saline 1         93.5            0.670140
# 11-23-21 DG     Fed STNS\n Fed Hemo           23.5            8.056935
#                 Fed STNS\n Saline 0           24.0            2.823660
#                 Fed STNS\n Saline 1           13.5            5.253795
#          GM     Fed STNS\n Fed Hemo           58.5            3.027105
#                 Fed STNS\n Saline 0           27.5            6.042870
#                 Fed STNS\n Saline 1           15.5            5.859111
#          LG     Fed STNS\n Fed Hemo           24.5            6.537915
#                 Fed STNS\n Saline 0           41.5            4.189860
#                 Fed STNS\n Saline 1           23.0            3.869100
#          MCN1R  Fed STNS\n Fed Hemo          347.0            0.661770
#                 Fed STNS\n Saline 0          293.0            0.703350
#                 Fed STNS\n Saline 1          128.5            0.297945
# 12-13-21 DG     Fed STNS\n Saline 0           27.0            4.424220
#                 Fed STNS\n Saline 1           28.5            4.511970
#                 Fed STNS\n unfed hemo         14.0            4.719330
#          GM     Fed STNS\n Saline 0            6.0           18.148320
#                 Fed STNS\n Saline 1           66.5            5.268780
#          LG     Fed STNS\n Saline 0           24.5            7.181190
#                 Fed STNS\n Saline 1           29.5            4.777245
#                 Fed STNS\n unfed hemo         12.0            6.652260
#          MCN1R  Fed STNS\n Saline 0          312.5            0.320625
#                 Fed STNS\n Saline 1          505.5            0.622350
#                 Fed STNS\n unfed hemo        160.5            0.864405
#          MG     Fed STNS\n Saline 0           28.5            4.968675
#                 Fed STNS\n Saline 1           38.0            9.420840
#                 Fed STNS\n unfed hemo         14.0            9.450540
# 3-3-22   GM     Fed STNS\n Fed Hemo           11.5            2.483190
#                 Fed STNS\n Saline 0           10.0            3.512700
#                 Fed STNS\n Saline 1            5.0            1.898640
#          LG     Fed STNS\n Saline 0           10.0            4.453920
#                 Fed STNS\n Saline 1            5.0            2.393820
#          MCN1L  Fed STNS\n Fed Hemo          160.0            0.545940
#                 Fed STNS\n Saline 0          227.5            0.505035
#                 Fed STNS\n Saline 1            2.5            9.446355
#
#                                        # of Spikes  Spike Frequency  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo           12.0         3.344318
#                 Fed STNS\n Saline 0           53.0        12.001327
#                 Fed STNS\n Saline 1           51.5         8.247112
#          LG     Fed STNS\n Fed Hemo            8.5         2.318663
#                 Fed STNS\n Saline 0           64.5         9.665517
#                 Fed STNS\n Saline 1           55.5         8.133319
#          MCN1R  Fed STNS\n Fed Hemo            1.0        35.615828
#                 Fed STNS\n Saline 0            9.0        13.141468
#                 Fed STNS\n Saline 1            6.0        11.902636
# 11-18-21 DG     Unfed STNS\n Fed Hemo         19.0         3.801330
#                 Unfed STNS\n Saline 0         21.0         3.680552
#                 Unfed STNS\n Saline 1         14.0         4.504157
#          LG     Unfed STNS\n Fed Hemo         23.0         6.595813
#                 Unfed STNS\n Saline 0         27.0         5.887894
#                 Unfed STNS\n Saline 1         31.0         6.667906
#          MCN1L  Unfed STNS\n Fed Hemo         15.0        14.229070
#                 Unfed STNS\n Saline 0          7.0        10.033253
#                 Unfed STNS\n Saline 1         34.0        11.101178
#          MCN1R  Unfed STNS\n Fed Hemo          3.0        14.224528
#                 Unfed STNS\n Saline 0          3.0         6.638952
#                 Unfed STNS\n Saline 1          8.5        18.579028
# 11-23-21 DG     Fed STNS\n Fed Hemo           56.0         7.245218
#                 Fed STNS\n Saline 0           14.0         4.867690
#                 Fed STNS\n Saline 1           27.5         5.562684
#          GM     Fed STNS\n Fed Hemo            5.0         2.844713
#                 Fed STNS\n Saline 0           18.0         2.767979
#                 Fed STNS\n Saline 1           12.0         2.211779
#          LG     Fed STNS\n Fed Hemo           38.5         5.519234
#                 Fed STNS\n Saline 0           17.0         3.951943
#                 Fed STNS\n Saline 1           14.0         3.671991
#          MCN1R  Fed STNS\n Fed Hemo            4.0         7.417297
#                 Fed STNS\n Saline 0            6.0         8.267196
#                 Fed STNS\n Saline 1            2.0         6.022298
# 12-13-21 DG     Fed STNS\n Saline 0           42.0         9.168394
#                 Fed STNS\n Saline 1           19.5         4.469327
#                 Fed STNS\n unfed hemo          9.0         2.118945
#          GM     Fed STNS\n Saline 0           44.0         2.371106
#                 Fed STNS\n Saline 1            8.5         2.326725
#          LG     Fed STNS\n Saline 0           77.5        11.173445
#                 Fed STNS\n Saline 1           23.0         4.835445
#                 Fed STNS\n unfed hemo         22.0         3.370962
#          MCN1R  Fed STNS\n Saline 0            3.0        11.986128
#                 Fed STNS\n Saline 1            7.0        10.638460
#                 Fed STNS\n unfed hemo          7.0         7.924640
#          MG     Fed STNS\n Saline 0           14.0         2.543653
#                 Fed STNS\n Saline 1           23.0         2.157581
#                 Fed STNS\n unfed hemo         16.0         1.669726
# 3-3-22   GM     Fed STNS\n Fed Hemo           27.5        10.330675
#                 Fed STNS\n Saline 0           54.0        15.379519
#                 Fed STNS\n Saline 1           25.0        14.103507
#          LG     Fed STNS\n Saline 0           32.0         6.807941
#                 Fed STNS\n Saline 1           18.0         6.949354
#          MCN1L  Fed STNS\n Fed Hemo            7.0        12.498438
#                 Fed STNS\n Saline 0            4.0         9.976347
#                 Fed STNS\n Saline 1          124.5        13.986118
#
#                                        Cycle Period  Duty Cycle  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo        8.309925    0.421805
#                 Fed STNS\n Saline 0       12.858885    0.363879
#                 Fed STNS\n Saline 1       16.782660    0.398594
#          LG     Fed STNS\n Fed Hemo        7.764390    0.385423
#                 Fed STNS\n Saline 0       14.159340    0.503864
#                 Fed STNS\n Saline 1       17.889120    0.392082
#          MCN1R  Fed STNS\n Fed Hemo        1.034370    0.027397
#                 Fed STNS\n Saline 0        1.198800    0.650103
#                 Fed STNS\n Saline 1        1.129410    0.515258
# 11-18-21 DG     Unfed STNS\n Fed Hemo      8.638110    0.463516
#                 Unfed STNS\n Saline 0     13.347045    0.398241
#                 Unfed STNS\n Saline 1      9.382770    0.335535
#          LG     Unfed STNS\n Fed Hemo      9.101970    0.376162
#                 Unfed STNS\n Saline 0     13.804560    0.353296
#                 Unfed STNS\n Saline 1      9.416790    0.496276
#          MCN1L  Unfed STNS\n Fed Hemo      1.441800    0.738404
#                 Unfed STNS\n Saline 0      1.039095    0.640426
#                 Unfed STNS\n Saline 1      3.186405    0.930912
#          MCN1R  Unfed STNS\n Fed Hemo      0.899370    0.381482
#                 Unfed STNS\n Saline 0      1.081350    0.428296
#                 Unfed STNS\n Saline 1      2.025810    0.463137
# 11-23-21 DG     Fed STNS\n Fed Hemo       22.869810    0.347865
#                 Fed STNS\n Saline 0       16.168005    0.177088
#                 Fed STNS\n Saline 1       18.127260    0.285137
#          GM     Fed STNS\n Fed Hemo        7.521930    0.422998
#                 Fed STNS\n Saline 0       11.982330    0.524463
#                 Fed STNS\n Saline 1       14.059440    0.419188
#          LG     Fed STNS\n Fed Hemo       22.492620    0.296792
#                 Fed STNS\n Saline 0       12.742380    0.352666
#                 Fed STNS\n Saline 1       16.681545    0.240800
#          MCN1R  Fed STNS\n Fed Hemo        1.407780    0.475570
#                 Fed STNS\n Saline 0        1.168155    0.596628
#                 Fed STNS\n Saline 1        1.345410    0.230003
# 12-13-21 DG     Fed STNS\n Saline 0       13.855455    0.364791
#                 Fed STNS\n Saline 1       23.283990    0.182683
#                 Fed STNS\n unfed hemo     17.217495    0.254640
#          GM     Fed STNS\n Saline 0       35.272800    0.908555
#                 Fed STNS\n Saline 1        8.509590    0.596622
#          LG     Fed STNS\n Saline 0       15.052230    0.453586
#                 Fed STNS\n Saline 1       23.619060    0.202375
#                 Fed STNS\n unfed hemo     19.695825    0.361081
#          MCN1R  Fed STNS\n Saline 0        0.710640    0.462207
#                 Fed STNS\n Saline 1        1.126710    0.558561
#                 Fed STNS\n unfed hemo      1.457190    0.592362
#          MG     Fed STNS\n Saline 0       13.479750    0.409018
#                 Fed STNS\n Saline 1       16.894079    0.762921
#                 Fed STNS\n unfed hemo     17.136630    0.566166
# 3-3-22   GM     Fed STNS\n Fed Hemo       17.898840    0.153390
#                 Fed STNS\n Saline 0       19.236015    0.184285
#                 Fed STNS\n Saline 1       12.154185    0.166449
#          LG     Fed STNS\n Saline 0       18.904050    0.253750
#                 Fed STNS\n Saline 1       12.306195    0.212755
#          MCN1L  Fed STNS\n Fed Hemo        1.023975    0.547930
#                 Fed STNS\n Saline 0        1.013040    0.508434
#                 Fed STNS\n Saline 1       11.889180    0.974134
#
#                                        Start of Burst (s)  Burst#  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo            746.356560     4.0
#                 Fed STNS\n Saline 0            863.988810    22.0
#                 Fed STNS\n Saline 1           1057.403580    20.5
#          LG     Fed STNS\n Fed Hemo            736.184145     2.5
#                 Fed STNS\n Saline 0            847.755165    20.5
#                 Fed STNS\n Saline 1           1032.023955    18.5
#          MCN1R  Fed STNS\n Fed Hemo            755.190645    26.5
#                 Fed STNS\n Saline 0           1048.311150    97.0
#                 Fed STNS\n Saline 1           1228.453665   210.5
# 11-18-21 DG     Unfed STNS\n Fed Hemo         8638.806075    11.5
#                 Unfed STNS\n Saline 0         1087.557720    39.0
#                 Unfed STNS\n Saline 1         1091.571270    24.0
#          LG     Unfed STNS\n Fed Hemo         8634.091305    11.5
#                 Unfed STNS\n Saline 0         1079.189310    38.0
#                 Unfed STNS\n Saline 1         1089.822450    23.5
#          MCN1L  Unfed STNS\n Fed Hemo         8658.034050    81.5
#                 Unfed STNS\n Saline 0         1202.500830   476.0
#                 Unfed STNS\n Saline 1         1166.980710    47.0
#          MCN1R  Unfed STNS\n Fed Hemo         8660.625810    70.5
#                 Unfed STNS\n Saline 0         1180.930425   186.5
#                 Unfed STNS\n Saline 1         1119.356520    93.5
# 11-23-21 DG     Fed STNS\n Fed Hemo           8571.279750    23.5
#                 Fed STNS\n Saline 0           1505.387580    24.0
#                 Fed STNS\n Saline 1           1888.504080    13.5
#          GM     Fed STNS\n Fed Hemo           8645.738940    58.5
#                 Fed STNS\n Saline 0           1504.417275    27.5
#                 Fed STNS\n Saline 1           1909.892182    15.5
#          LG     Fed STNS\n Fed Hemo           8577.623910    24.5
#                 Fed STNS\n Saline 0           1430.894010    41.5
#                 Fed STNS\n Saline 1           1904.270970    23.0
#          MCN1R  Fed STNS\n Fed Hemo           8563.231410   347.0
#                 Fed STNS\n Saline 0           1482.972810   293.0
#                 Fed STNS\n Saline 1           1926.337920   128.5
# 12-13-21 DG     Fed STNS\n Saline 0            912.353370    27.0
#                 Fed STNS\n Saline 1           2573.774205    28.5
#                 Fed STNS\n unfed hemo         2970.452130    14.0
#          GM     Fed STNS\n Saline 0           1144.761210     6.0
#                 Fed STNS\n Saline 1           2611.991025    66.5
#          LG     Fed STNS\n Saline 0            880.289490    24.5
#                 Fed STNS\n Saline 1           2604.498690    29.5
#                 Fed STNS\n unfed hemo         2960.424300    12.0
#          MCN1R  Fed STNS\n Saline 0           1033.927980   312.5
#                 Fed STNS\n Saline 1           2757.781590   505.5
#                 Fed STNS\n unfed hemo         3060.980790   160.5
#          MG     Fed STNS\n Saline 0            904.865085    28.5
#                 Fed STNS\n Saline 1           2421.202770    38.0
#                 Fed STNS\n unfed hemo         2973.979710    14.0
# 3-3-22   GM     Fed STNS\n Fed Hemo           1132.531530    11.5
#                 Fed STNS\n Saline 0           1669.581780    10.0
#                 Fed STNS\n Saline 1           1984.560000     5.0
#          LG     Fed STNS\n Saline 0           1669.363650    10.0
#                 Fed STNS\n Saline 1           1983.348210     5.0
#          MCN1L  Fed STNS\n Fed Hemo           1205.849100   160.0
#                 Fed STNS\n Saline 0           1939.110780   227.5
#                 Fed STNS\n Saline 1           2046.392310     2.5
#
#                                        Burst Duration (sec)  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo                3.836430
#                 Fed STNS\n Saline 0                4.586220
#                 Fed STNS\n Saline 1                6.572880
#          LG     Fed STNS\n Fed Hemo                3.370140
#                 Fed STNS\n Saline 0                6.859485
#                 Fed STNS\n Saline 1                6.864075
#          MCN1R  Fed STNS\n Fed Hemo                0.028080
#                 Fed STNS\n Saline 0                0.732780
#                 Fed STNS\n Saline 1                0.564975
# 11-18-21 DG     Unfed STNS\n Fed Hemo              4.058100
#                 Unfed STNS\n Saline 0              5.452380
#                 Unfed STNS\n Saline 1              3.060180
#          LG     Unfed STNS\n Fed Hemo              3.879765
#                 Unfed STNS\n Saline 0              4.854330
#                 Unfed STNS\n Saline 1              4.894560
#          MCN1L  Unfed STNS\n Fed Hemo              1.045170
#                 Unfed STNS\n Saline 0              0.678240
#                 Unfed STNS\n Saline 1              2.914380
#          MCN1R  Unfed STNS\n Fed Hemo              0.244755
#                 Unfed STNS\n Saline 0              0.397845
#                 Unfed STNS\n Saline 1              0.670140
# 11-23-21 DG     Fed STNS\n Fed Hemo                8.056935
#                 Fed STNS\n Saline 0                2.823660
#                 Fed STNS\n Saline 1                5.253795
#          GM     Fed STNS\n Fed Hemo                3.027105
#                 Fed STNS\n Saline 0                6.042870
#                 Fed STNS\n Saline 1                5.859111
#          LG     Fed STNS\n Fed Hemo                6.537915
#                 Fed STNS\n Saline 0                4.189860
#                 Fed STNS\n Saline 1                3.869100
#          MCN1R  Fed STNS\n Fed Hemo                0.661770
#                 Fed STNS\n Saline 0                0.703350
#                 Fed STNS\n Saline 1                0.297945
# 12-13-21 DG     Fed STNS\n Saline 0                4.424220
#                 Fed STNS\n Saline 1                4.511970
#                 Fed STNS\n unfed hemo              4.719330
#          GM     Fed STNS\n Saline 0               18.148320
#                 Fed STNS\n Saline 1                5.268780
#          LG     Fed STNS\n Saline 0                7.181190
#                 Fed STNS\n Saline 1                4.777245
#                 Fed STNS\n unfed hemo              6.652260
#          MCN1R  Fed STNS\n Saline 0                0.320625
#                 Fed STNS\n Saline 1                0.622350
#                 Fed STNS\n unfed hemo              0.864405
#          MG     Fed STNS\n Saline 0                4.968675
#                 Fed STNS\n Saline 1                9.420840
#                 Fed STNS\n unfed hemo              9.450540
# 3-3-22   GM     Fed STNS\n Fed Hemo                2.483190
#                 Fed STNS\n Saline 0                3.512700
#                 Fed STNS\n Saline 1                1.898640
#          LG     Fed STNS\n Saline 0                4.453920
#                 Fed STNS\n Saline 1                2.393820
#          MCN1L  Fed STNS\n Fed Hemo                0.545940
#                 Fed STNS\n Saline 0                0.505035
#                 Fed STNS\n Saline 1                9.446355
#
#                                        Spike Frequency (Hz)  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo                3.344318
#                 Fed STNS\n Saline 0               12.001327
#                 Fed STNS\n Saline 1                8.247112
#          LG     Fed STNS\n Fed Hemo                2.318663
#                 Fed STNS\n Saline 0                9.665517
#                 Fed STNS\n Saline 1                8.133319
#          MCN1R  Fed STNS\n Fed Hemo               35.615828
#                 Fed STNS\n Saline 0               13.141468
#                 Fed STNS\n Saline 1               11.902636
# 11-18-21 DG     Unfed STNS\n Fed Hemo              3.801330
#                 Unfed STNS\n Saline 0              3.680552
#                 Unfed STNS\n Saline 1              4.504157
#          LG     Unfed STNS\n Fed Hemo              6.595813
#                 Unfed STNS\n Saline 0              5.887894
#                 Unfed STNS\n Saline 1              6.667906
#          MCN1L  Unfed STNS\n Fed Hemo             14.229070
#                 Unfed STNS\n Saline 0             10.033253
#                 Unfed STNS\n Saline 1             11.101178
#          MCN1R  Unfed STNS\n Fed Hemo             14.224528
#                 Unfed STNS\n Saline 0              6.638952
#                 Unfed STNS\n Saline 1             18.579028
# 11-23-21 DG     Fed STNS\n Fed Hemo                7.245218
#                 Fed STNS\n Saline 0                4.867690
#                 Fed STNS\n Saline 1                5.562684
#          GM     Fed STNS\n Fed Hemo                2.844713
#                 Fed STNS\n Saline 0                2.767979
#                 Fed STNS\n Saline 1                2.211779
#          LG     Fed STNS\n Fed Hemo                5.519234
#                 Fed STNS\n Saline 0                3.951943
#                 Fed STNS\n Saline 1                3.671991
#          MCN1R  Fed STNS\n Fed Hemo                7.417297
#                 Fed STNS\n Saline 0                8.267196
#                 Fed STNS\n Saline 1                6.022298
# 12-13-21 DG     Fed STNS\n Saline 0                9.168394
#                 Fed STNS\n Saline 1                4.469327
#                 Fed STNS\n unfed hemo              2.118945
#          GM     Fed STNS\n Saline 0                2.371106
#                 Fed STNS\n Saline 1                2.326725
#          LG     Fed STNS\n Saline 0               11.173445
#                 Fed STNS\n Saline 1                4.835445
#                 Fed STNS\n unfed hemo              3.370962
#          MCN1R  Fed STNS\n Saline 0               11.986128
#                 Fed STNS\n Saline 1               10.638460
#                 Fed STNS\n unfed hemo              7.924640
#          MG     Fed STNS\n Saline 0                2.543653
#                 Fed STNS\n Saline 1                2.157581
#                 Fed STNS\n unfed hemo              1.669726
# 3-3-22   GM     Fed STNS\n Fed Hemo               10.330675
#                 Fed STNS\n Saline 0               15.379519
#                 Fed STNS\n Saline 1               14.103507
#          LG     Fed STNS\n Saline 0                6.807941
#                 Fed STNS\n Saline 1                6.949354
#          MCN1L  Fed STNS\n Fed Hemo               12.498438
#                 Fed STNS\n Saline 0                9.976347
#                 Fed STNS\n Saline 1               13.986118
#
#                                        Instantaneous Period (sec)  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo                      8.309925
#                 Fed STNS\n Saline 0                     12.858885
#                 Fed STNS\n Saline 1                     16.782660
#          LG     Fed STNS\n Fed Hemo                      7.764390
#                 Fed STNS\n Saline 0                     14.159340
#                 Fed STNS\n Saline 1                     17.889120
#          MCN1R  Fed STNS\n Fed Hemo                      1.034370
#                 Fed STNS\n Saline 0                      1.198800
#                 Fed STNS\n Saline 1                      1.129410
# 11-18-21 DG     Unfed STNS\n Fed Hemo                    8.638110
#                 Unfed STNS\n Saline 0                   13.347045
#                 Unfed STNS\n Saline 1                    9.382770
#          LG     Unfed STNS\n Fed Hemo                    9.101970
#                 Unfed STNS\n Saline 0                   13.804560
#                 Unfed STNS\n Saline 1                    9.416790
#          MCN1L  Unfed STNS\n Fed Hemo                    1.441800
#                 Unfed STNS\n Saline 0                    1.039095
#                 Unfed STNS\n Saline 1                    3.186405
#          MCN1R  Unfed STNS\n Fed Hemo                    0.899370
#                 Unfed STNS\n Saline 0                    1.081350
#                 Unfed STNS\n Saline 1                    2.025810
# 11-23-21 DG     Fed STNS\n Fed Hemo                     22.869810
#                 Fed STNS\n Saline 0                     16.168005
#                 Fed STNS\n Saline 1                     18.127260
#          GM     Fed STNS\n Fed Hemo                      7.521930
#                 Fed STNS\n Saline 0                     11.982330
#                 Fed STNS\n Saline 1                     14.059440
#          LG     Fed STNS\n Fed Hemo                     22.492620
#                 Fed STNS\n Saline 0                     12.742380
#                 Fed STNS\n Saline 1                     16.681545
#          MCN1R  Fed STNS\n Fed Hemo                      1.407780
#                 Fed STNS\n Saline 0                      1.168155
#                 Fed STNS\n Saline 1                      1.345410
# 12-13-21 DG     Fed STNS\n Saline 0                     13.855455
#                 Fed STNS\n Saline 1                     23.283990
#                 Fed STNS\n unfed hemo                   17.217495
#          GM     Fed STNS\n Saline 0                     35.272800
#                 Fed STNS\n Saline 1                      8.509590
#          LG     Fed STNS\n Saline 0                     15.052230
#                 Fed STNS\n Saline 1                     23.619060
#                 Fed STNS\n unfed hemo                   19.695825
#          MCN1R  Fed STNS\n Saline 0                      0.710640
#                 Fed STNS\n Saline 1                      1.126710
#                 Fed STNS\n unfed hemo                    1.457190
#          MG     Fed STNS\n Saline 0                     13.479750
#                 Fed STNS\n Saline 1                     16.894079
#                 Fed STNS\n unfed hemo                   17.136630
# 3-3-22   GM     Fed STNS\n Fed Hemo                     17.898840
#                 Fed STNS\n Saline 0                     19.236015
#                 Fed STNS\n Saline 1                     12.154185
#          LG     Fed STNS\n Saline 0                     18.904050
#                 Fed STNS\n Saline 1                     12.306195
#          MCN1L  Fed STNS\n Fed Hemo                      1.023975
#                 Fed STNS\n Saline 0                      1.013040
#                 Fed STNS\n Saline 1                     11.889180
#
#                                        Instantaneous Frequency (Hz)  \
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo                        0.120394
#                 Fed STNS\n Saline 0                        0.077794
#                 Fed STNS\n Saline 1                        0.059585
#          LG     Fed STNS\n Fed Hemo                        0.128793
#                 Fed STNS\n Saline 0                        0.070625
#                 Fed STNS\n Saline 1                        0.055900
#          MCN1R  Fed STNS\n Fed Hemo                        0.966772
#                 Fed STNS\n Saline 0                        0.834211
#                 Fed STNS\n Saline 1                        0.885418
# 11-18-21 DG     Unfed STNS\n Fed Hemo                      0.115766
#                 Unfed STNS\n Saline 0                      0.074924
#                 Unfed STNS\n Saline 1                      0.106593
#          LG     Unfed STNS\n Fed Hemo                      0.109866
#                 Unfed STNS\n Saline 0                      0.072440
#                 Unfed STNS\n Saline 1                      0.106193
#          MCN1L  Unfed STNS\n Fed Hemo                      0.693577
#                 Unfed STNS\n Saline 0                      0.962376
#                 Unfed STNS\n Saline 1                      0.313838
#          MCN1R  Unfed STNS\n Fed Hemo                      1.111889
#                 Unfed STNS\n Saline 0                      0.924770
#                 Unfed STNS\n Saline 1                      0.493630
# 11-23-21 DG     Fed STNS\n Fed Hemo                        0.043726
#                 Fed STNS\n Saline 0                        0.061894
#                 Fed STNS\n Saline 1                        0.055166
#          GM     Fed STNS\n Fed Hemo                        0.132945
#                 Fed STNS\n Saline 0                        0.083456
#                 Fed STNS\n Saline 1                        0.071127
#          LG     Fed STNS\n Fed Hemo                        0.044459
#                 Fed STNS\n Saline 0                        0.078478
#                 Fed STNS\n Saline 1                        0.059947
#          MCN1R  Fed STNS\n Fed Hemo                        0.710338
#                 Fed STNS\n Saline 0                        0.856051
#                 Fed STNS\n Saline 1                        0.743268
# 12-13-21 DG     Fed STNS\n Saline 0                        0.072174
#                 Fed STNS\n Saline 1                        0.042948
#                 Fed STNS\n unfed hemo                      0.058085
#          GM     Fed STNS\n Saline 0                        0.033619
#                 Fed STNS\n Saline 1                        0.117514
#          LG     Fed STNS\n Saline 0                        0.066435
#                 Fed STNS\n Saline 1                        0.042339
#                 Fed STNS\n unfed hemo                      0.050772
#          MCN1R  Fed STNS\n Saline 0                        1.407182
#                 Fed STNS\n Saline 1                        0.887540
#                 Fed STNS\n unfed hemo                      0.686252
#          MG     Fed STNS\n Saline 0                        0.074185
#                 Fed STNS\n Saline 1                        0.059215
#                 Fed STNS\n unfed hemo                      0.058377
# 3-3-22   GM     Fed STNS\n Fed Hemo                        0.055870
#                 Fed STNS\n Saline 0                        0.051987
#                 Fed STNS\n Saline 1                        0.082457
#          LG     Fed STNS\n Saline 0                        0.052965
#                 Fed STNS\n Saline 1                        0.081374
#          MCN1L  Fed STNS\n Fed Hemo                        0.976587
#                 Fed STNS\n Saline 0                        0.987128
#                 Fed STNS\n Saline 1                        0.084110
#
#                                        Interburst Duration (s)
# Date     Neuron Condition
# 1-13-22  DG     Fed STNS\n Fed Hemo                   4.954635
#                 Fed STNS\n Saline 0                   8.543205
#                 Fed STNS\n Saline 1                  10.073970
#          LG     Fed STNS\n Fed Hemo                   4.817340
#                 Fed STNS\n Saline 0                   6.686550
#                 Fed STNS\n Saline 1                  10.859670
#          MCN1R  Fed STNS\n Fed Hemo                   1.011690
#                 Fed STNS\n Saline 0                   0.432810
#                 Fed STNS\n Saline 1                   0.538920
# 11-18-21 DG     Unfed STNS\n Fed Hemo                 5.064390
#                 Unfed STNS\n Saline 0                 7.748865
#                 Unfed STNS\n Saline 1                 6.164100
#          LG     Unfed STNS\n Fed Hemo                 5.448870
#                 Unfed STNS\n Saline 0                 8.934435
#                 Unfed STNS\n Saline 1                 4.878630
#          MCN1L  Unfed STNS\n Fed Hemo                 0.390150
#                 Unfed STNS\n Saline 0                 0.342495
#                 Unfed STNS\n Saline 1                 0.227610
#          MCN1R  Unfed STNS\n Fed Hemo                 0.354780
#                 Unfed STNS\n Saline 0                 0.527850
#                 Unfed STNS\n Saline 1                 0.362610
# 11-23-21 DG     Fed STNS\n Fed Hemo                  14.599170
#                 Fed STNS\n Saline 0                  12.770730
#                 Fed STNS\n Saline 1                  12.063600
#          GM     Fed STNS\n Fed Hemo                   3.098520
#                 Fed STNS\n Saline 0                   4.123980
#                 Fed STNS\n Saline 1                   5.098140
#          LG     Fed STNS\n Fed Hemo                  15.422670
#                 Fed STNS\n Saline 0                   7.803270
#                 Fed STNS\n Saline 1                  12.707550
#          MCN1R  Fed STNS\n Fed Hemo                   0.674190
#                 Fed STNS\n Saline 0                   0.451845
#                 Fed STNS\n Saline 1                   0.937170
# 12-13-21 DG     Fed STNS\n Saline 0                   8.878545
#                 Fed STNS\n Saline 1                  19.029600
#                 Fed STNS\n unfed hemo                13.102695
#          GM     Fed STNS\n Saline 0                   3.044250
#                 Fed STNS\n Saline 1                   2.780190
#          LG     Fed STNS\n Saline 0                   8.212590
#                 Fed STNS\n Saline 1                  18.837360
#                 Fed STNS\n unfed hemo                11.833425
#          MCN1R  Fed STNS\n Saline 0                   0.387180
#                 Fed STNS\n Saline 1                   0.483840
#                 Fed STNS\n unfed hemo                 0.568080
#          MG     Fed STNS\n Saline 0                   8.303580
#                 Fed STNS\n Saline 1                   2.688660
#                 Fed STNS\n unfed hemo                 5.488695
# 3-3-22   GM     Fed STNS\n Fed Hemo                  15.402960
#                 Fed STNS\n Saline 0                  15.765975
#                 Fed STNS\n Saline 1                  10.425240
#          LG     Fed STNS\n Saline 0                  14.768460
#                 Fed STNS\n Saline 1                   9.699750
#          MCN1L  Fed STNS\n Fed Hemo                   0.463860
#                 Fed STNS\n Saline 0                   0.513000
#                 Fed STNS\n Saline 1                   0.341280

# %% [markdown]
# # Line Plot

# %%
@widgets.interact(
    y_val=y_val_options, 
    burst_num=(1, 20),
    neuron = neuron_options, 
    Condition = widgets.SelectMultiple(
        options=cond_options,
        value=tuple(cond_options),
        rows = len(cond_options),
        description='Condition',
        disabled=False),
    dates=widgets.SelectMultiple(
        options=dates,
        value=dates,
        rows=len(dates),
        description='dates',
        disabled=False
        ))


def plot(y_val='Burst Duration (sec)', burst_num=20, plot_lines=True, 
         title='Plot title', neuron='LG',dates=dates, Condition='Pre',
        ):
    global dataframe
    global marker_d
    global color_d
    _dataframe = dataframe[(dataframe['Burst#'] < burst_num)
                           &(dataframe['Neuron']==neuron)
                           #&(dataframe['Condition']==condition)
                           &(dataframe.Condition.isin(Condition))
                           &(dataframe.Date.isin(dates))]
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,5))
    for i,date in enumerate(_dataframe['Date'].unique()):
        data = _dataframe[_dataframe['Date']==date]
        plot = ax.scatter(x=data['Burst#'], 
                          y=data[y_val], 
                          label='{} {}'.format(date, neuron),
                          alpha=.5,
                          marker=marker_d[date],
                          color=color_d[date]
                         )
        if plot_lines:
            if data[data['Burst#']==1].shape[0] == 1:
                plot_ = ax.plot(data['Burst#'], 
                                data[y_val], color=color_d[date], ls='--',zorder=3, label='')
            elif data[data['Burst#']==1].shape[0] > 1:
                # Fix the issue here
                # This hassle and weird code is to prevent line connections between seperate
                # Experiments
                #x_data = find_consecutive_data(data['Burst#'])
                x_data = np.split(data['Burst#'],
                                  np.where(np.diff(data['Burst#']) != 1)[0] + 1)
                y_data = np.split(data[y_val], 
                                  np.where(np.diff(data['Burst#']) != 1)[0] + 1)
                for x,y in zip(x_data, y_data):
                    plot_ = ax.plot(x, y, color=color_d[date], ls='--',zorder=3, label='')
                
                

    y_label = ax.set_ylabel(y_val,fontsize=16)
    x_label = ax.set_xlabel('Burst #',fontsize=16)
    ax.set_title(title,fontsize=20)
    plt.legend(bbox_to_anchor=(1,1))
    plt.tight_layout()
# Out:
# interactive(children=(Dropdown(description='y_val', options=('Burst Duration (sec)', '# of Spikes', 'Spike Fre…

# %% [markdown]
# # UTILITY functions to be implemented if necessary

# %%
def modified_z_score(array, axis=-1):
    """Applies a modified z on the inputted array

    :param array: np.array, array to calc mod zscore over
    :param axis: int, axis over which to apply
    :return: modified zscore
    """
    # Below is basically copying how it's done in scipy.stat.zscore
    # .6745 is constant for conversion 
    a = np.asanyarray(array)
    median = np.nanmedian(a, axis=axis)
    median_absolute_deviation = np.nanmedian(np.abs(a - median), axis=axis)

    if axis and median_absolute_deviation.ndim < a.ndim:
        return ((0.6745 * (a - np.expand_dims(median, axis=axis))) /
                np.expand_dims(median_absolute_deviation, axis=axis))
    else:
        return (0.6745 * (a - median)) / median_absolute_deviation


def outliers_modified_z_score(array, threshold=3.5, axis=-1):
    """Return an array to mask at all points that are not outliers

    :param array: np.array, array to calc mod zscore over
    :param threshold: float, value at which to threshold
    :param axis: int, axis over which to apply
    :return: masked_array: array to mask at all points that are not outliers
    """
    modified_z_scores = modified_z_score(array, axis=axis)
    return np.where(np.abs(modified_z_scores) > threshold)


def legend_without_duplicate_labels(ax, **kwargs):
    """Pass in an axis from matplotlib, will return a legend without duplicate entries in it

    :param ax: mpl.ax, axis with corresponding legend
    :param kwargs:
    :return:
    """
    handles, labels = ax.get_legend_handles_labels()
    unique = [(h, l) for i, (h, l) in enumerate(zip(handles, labels)) if l not in labels[:i]]
    ax.legend(*zip(*unique), **kwargs)
    

def reorder_df(df, list_of_order, by='Condition'):
    assert(len(list_of_order)==len(df.groupby(by)))
    return pd.concat([df[df[by]==cond]for cond in list_of_order])
        
order = ['Unfed STNS\n Saline 0','Fed STNS\n Saline 0',
         'Unfed STNS\n Fed Hemo', 'Fed STNS\n unfed hemo', 'Fed STNS\n Fed Hemo',
         'Unfed STNS\n Saline 1', 'Fed STNS\n Saline 1',]

sns.set_context('notebook')

# %%
@widgets.interact(
    y_val=y_val_options, 
    burst_num=(1, 50),
    #neuron = neuron_options,
    neuron = widgets.Select(
        options=neuron_options, 
        value='LG',#tuple(kind), 
        rows=1, 
        description='Neuron', 
        disabled=False),
    kind = widgets.Select(
        options=kind, 
        value='violin',#tuple(kind), 
        rows=1, 
        description='Plot Kind', 
        disabled=False),
    Condition = widgets.SelectMultiple(
        options=cond_options,
        value=tuple(cond_options),
        rows = len(cond_options),
        description='Condition',
        disabled=False),
    dates=widgets.SelectMultiple(
        options=dates,
        value=dates,
        rows=len(dates),
        description='dates',
        disabled=False),
    y_lim = widgets.FloatRangeSlider(value=(0, 100), min=0, max=100)
    #apples=widgets.Checkbox(),
)



def plot(y_val='Burst Duration (sec)', burst_num=20, kind='violin', 
         title='{} {}', neuron='LG',dates=dates, Condition='Saline 0',
         apples=False, palette='colorblind', y_lim=(0,50)
        ):
    global dataframe
    global data_apples
    global marker_d
    global color_d
    
    if apples:
        print('Running Apples to Apples')
        _dataframe = data_apples[((data_apples['Burst#'] < burst_num))]
                                 #&(data_apples.Condition.isin(Condition))
                                 #&(data_apples.Date.isin(dates))]
        df = data_apples[(data_apples['Burst#'] < burst_num)
                        &(data_apples['Condition'].isin(Condition))
                        &(data_apples['Date'].isin(dates))]
        
    if not apples:
        _dataframe = dataframe[(dataframe['Burst#'] < burst_num)
                               &(dataframe.Condition.isin(Condition))
                               &(dataframe.Date.isin(dates))]
    if type(neuron)==str:
        _dataframe = _dataframe[_dataframe['Neuron']==neuron]
    elif type(neuron)== list:
        _dataframe = _dataframe[_dataframe['Neuron'].isin(neuron)]
        
    if type(Condition)==str:
        Condition = _dataframe[_dataframe['Neuron']==Condition]
    elif type(neuron)== list:
        _dataframe = _dataframe[_dataframe['Condition'].isin(Condition)]
        
        
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
    
    pal = palette
    sns.set_palette(pal)
    
    if kind == 'violin':
        #if apples:
            
            
        g = sns.violinplot(x='Condition',
                           y=y_val,
                           data=_dataframe,
                           hue='Date',
                           scale_hue=False,
                           inner='box',
                           scale='width',
                           split=False,
                           ax=ax,
                           bw='scott',
                           cut=0,
                          )
        
    if kind == 'strip':
        g= sns.stripplot(x="Condition",
                         y=y_val,
                         hue='Date',
                         data=_dataframe,
                         #order='Date',
                         #hue_order=None,
                         dodge=True,
                         size=5,
                         edgecolor='gray',
                         linewidth=0,
                         ax=ax,)
        
    elif kind == 'line':
        
        g = sns.pointplot(x="Condition",
                          y=y_val,
                          hue="Date",
                          capsize=.2,
                          #palette=pal,
                          ci='sd',
                          kind="point",
                          data=_dataframe,
                          ax=ax,
                          )

    elif kind =='scatter':
        """for condition in _dataframe['Condition'].unique():
            data = _dataframe[_dataframe['Condition'] == condition]
            g = ax.scatter(x=data['Burst#'],
                           y=data[y_val],
                           label='{} {} Neuron'.format(condition, neuron),
                           alpha=.5,
         
                          )"""
        
        g= sns.scatterplot(x="Burst#",
                           y=y_val,
                           hue='Date',
                           data=data,
                           style='Condition',
                           size=2,
                           edgecolor='black',
                           linewidth=0, 
                           alpha=.5,
                           ax=ax)

    y_label = ax.set_ylabel(y_val, fontsize=16)
    x_label = ax.set_xlabel('Burst #', fontsize=16)
    legend_without_duplicate_labels(ax=ax)
    ax.legend(bbox_to_anchor=(1.1, 1.05))
    
    plt.title(title.format(y_val, neuron), fontsize=25)
    
    ax.set_ylim(y_lim)
    plt.tight_layout()
# Out:
# interactive(children=(Dropdown(description='y_val', options=('Burst Duration (sec)', '# of Spikes', 'Spike Fre…
